# %% [markdown]
# The data used in this application originates from Excel files (5308.xls and 5329.xls). The CSV files (cell_5308.csv and cell_5329.csv) were created by extracting specific columns from these Excel files

# %%
import pandas as pd

# %%
# !pip install xlrd
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Reading 5308.xls file
df = pd.read_excel('5308.xls',sheet_name='Detail_67_3_5')

# %%
df
# Out:
#        Record Index Status  JumpTo  Cycle  Step  Cur(mA)  Voltage(V)  \
# 0                 1   Rest       1      1     1      0.0      3.5900
# 1                 2   Rest       1      1     1      0.0      3.5900
# 2                 3   Rest       1      1     1      0.0      3.5900
# 3                 4   Rest       1      1     1      0.0      3.5900
# 4                 5   Rest       1      1     1      0.0      3.5900
# ...             ...    ...     ...    ...   ...      ...         ...
# 29398         29399   Rest      10      3    10      0.0      3.5925
# 29399         29400   Rest      10      3    10      0.0      3.5921
# 29400         29401   Rest      10      3    10      0.0      3.5921
# 29401         29402   Rest      10      3    10      0.0      3.5921
# 29402         29403   Rest      10      3    10      0.0      3.5921
#
#        CapaCity(mAh)  Energy(mWh) Relative Time(h:min:s.ms)  \
# 0                0.0          0.0               0:00:00.000
# ...

# %%
df.drop(["Status","JumpTo","Cycle","Step","Relative Time(h:min:s.ms)"],inplace=True,axis=1)

# %%
df.head()
# Out:
#    Record Index  Cur(mA)  Voltage(V)  CapaCity(mAh)  Energy(mWh)  \
# 0             1      0.0        3.59            0.0          0.0
# 1             2      0.0        3.59            0.0          0.0
# 2             3      0.0        3.59            0.0          0.0
# 3             4      0.0        3.59            0.0          0.0
# 4             5      0.0        3.59            0.0          0.0
#
#         Absolute Time
# 0 2019-11-15 19:28:43
# 1 2019-11-15 19:28:44
# 2 2019-11-15 19:28:45
# 3 2019-11-15 19:28:46
# 4 2019-11-15 19:28:47

# %%
df_temp = pd.read_excel('5308.xls',sheet_name='DetailTemp_67_3_5')

# %%
df_temp=df_temp["Auxiliary channel TU1 T(°C)"]

# %%
df_temp.head()
# Out:
# 0    37.4
# 1    37.4
# 2    37.4
# 3    37.4
# 4    37.3
# Name: Auxiliary channel TU1 T(°C), dtype: float64

# %%
df_final = pd.concat([df,df_temp],axis=1)

# %%
df_final.head()
# Out:
#    Record Index  Cur(mA)  Voltage(V)  CapaCity(mAh)  Energy(mWh)  \
# 0             1      0.0        3.59            0.0          0.0
# 1             2      0.0        3.59            0.0          0.0
# 2             3      0.0        3.59            0.0          0.0
# 3             4      0.0        3.59            0.0          0.0
# 4             5      0.0        3.59            0.0          0.0
#
#         Absolute Time  Auxiliary channel TU1 T(°C)
# 0 2019-11-15 19:28:43                         37.4
# 1 2019-11-15 19:28:44                         37.4
# 2 2019-11-15 19:28:45                         37.4
# 3 2019-11-15 19:28:46                         37.4
# 4 2019-11-15 19:28:47                         37.3

# %%
final_data = {
    "Record Index":df_final["Record Index"],
    "Current":df_final["Cur(mA)"],
    "Voltage":df_final["Voltage(V)"],
    "Capacity":df_final["CapaCity(mAh)"],
    "Temperature":df_final["Auxiliary channel TU1 T(°C)"],
    "Time":df_final["Absolute Time"], 
}

# %%
save_to_csv = pd.DataFrame(final_data)

# %%
save_to_csv.to_csv("cell_5308.csv",index=False)

# %%
# Reading 5329.xls file
df2 = pd.read_excel('5329.xls',sheet_name='Detail_67_3_1')

# %%
df2
# Out:
#        Record Index Status  JumpTo  Cycle  Step  Cur(mA)  Voltage(V)  \
# 0                 1   Rest       1      1     1      0.0      3.5897
# 1                 2   Rest       1      1     1      0.0      3.5897
# 2                 3   Rest       1      1     1      0.0      3.5897
# 3                 4   Rest       1      1     1      0.0      3.5897
# 4                 5   Rest       1      1     1      0.0      3.5897
# ...             ...    ...     ...    ...   ...      ...         ...
# 29597         29598   Rest      10      3    10      0.0      3.5928
# 29598         29599   Rest      10      3    10      0.0      3.5928
# 29599         29600   Rest      10      3    10      0.0      3.5928
# 29600         29601   Rest      10      3    10      0.0      3.5928
# 29601         29602   Rest      10      3    10      0.0      3.5928
#
#        CapaCity(mAh)  Energy(mWh) Relative Time(h:min:s.ms)  \
# 0                0.0          0.0               0:00:00.000
# ...

# %%
df2.drop(["Status","JumpTo","Cycle","Step","Relative Time(h:min:s.ms)"],inplace=True,axis=1)

# %%
df2.head()
# Out:
#    Record Index  Cur(mA)  Voltage(V)  CapaCity(mAh)  Energy(mWh)  \
# 0             1      0.0      3.5897            0.0          0.0
# 1             2      0.0      3.5897            0.0          0.0
# 2             3      0.0      3.5897            0.0          0.0
# 3             4      0.0      3.5897            0.0          0.0
# 4             5      0.0      3.5897            0.0          0.0
#
#         Absolute Time
# 0 2019-11-15 19:38:18
# 1 2019-11-15 19:38:19
# 2 2019-11-15 19:38:20
# 3 2019-11-15 19:38:21
# 4 2019-11-15 19:38:22

# %%
df_temp2 = pd.read_excel('5329.xls',sheet_name='DetailTemp_67_3_1')

# %%
df_temp2=df_temp2["Auxiliary channel TU1 T(°C)"]

# %%
df_temp2.head()
# Out:
# 0    32.2
# 1    32.3
# 2    32.1
# 3    32.2
# 4    32.1
# Name: Auxiliary channel TU1 T(°C), dtype: float64

# %%
df_final2 = pd.concat([df2,df_temp2],axis=1)

# %%
df_final2.head()
# Out:
#    Record Index  Cur(mA)  Voltage(V)  CapaCity(mAh)  Energy(mWh)  \
# 0             1      0.0      3.5897            0.0          0.0
# 1             2      0.0      3.5897            0.0          0.0
# 2             3      0.0      3.5897            0.0          0.0
# 3             4      0.0      3.5897            0.0          0.0
# 4             5      0.0      3.5897            0.0          0.0
#
#         Absolute Time  Auxiliary channel TU1 T(°C)
# 0 2019-11-15 19:38:18                         32.2
# 1 2019-11-15 19:38:19                         32.3
# 2 2019-11-15 19:38:20                         32.1
# 3 2019-11-15 19:38:21                         32.2
# 4 2019-11-15 19:38:22                         32.1

# %%
final_data2 = {
    "Record Index":df_final2["Record Index"],
    "Current":df_final2["Cur(mA)"],
    "Voltage":df_final2["Voltage(V)"],
    "Capacity":df_final2["CapaCity(mAh)"],
    "Temperature":df_final2["Auxiliary channel TU1 T(°C)"],
    "Time":df_final2["Absolute Time"], 
}

# %%
save_to_csv2 = pd.DataFrame(final_data2)

# %%
save_to_csv2.to_csv("cell_5329.csv",index=False)
